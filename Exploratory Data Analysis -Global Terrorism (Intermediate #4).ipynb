# %% [markdown]
# # Exploratory Data Analysis - Terrorism(TASK 4)
# # Sameer Dhole
# # #GRIPFEB21

# %% [raw]
# import numpy as np # linear algebra
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# import dask.dataframe as dd

# %%
df=pd.read_csv(r"C:\Users\dhole\Downloads\Global Terrorism\globalterrorismdb_0718dist.csv",encoding='latin1',dtype='unicode',low_memory=False)

# %%
df.tail(9)
# Out:
#             eventid iyear imonth iday  country_txt  \
# 181682  2.01712E+11  2017     12   31        Italy
# 181683  2.01712E+11  2017     12   31  Afghanistan
# 181684  2.01712E+11  2017     12   31        India
# 181685  2.01712E+11  2017     12   31  Afghanistan
# 181686  2.01712E+11  2017     12   31      Somalia
# 181687  2.01712E+11  2017     12   31        Syria
# 181688  2.01712E+11  2017     12   31  Philippines
# 181689  2.01712E+11  2017     12   31        India
# 181690  2.01712E+11  2017     12   31  Philippines
#
#                         region_txt        provstate               city  \
# 181682              Western Europe           Marche          Spinetoli
# 181683                  South Asia           Faryab  Kohistan district
# 181684                  South Asia            Assam            Hungrum
# 181685                  South Asia           Faryab            Maymana
# 181686          Sub-Saharan Africa  Middle Shebelle      Ceelka Geelow
# ...

# %%
df.isnull().sum()
# Out:
# eventid                  0
# iyear                    0
# imonth                   0
# iday                     0
# country_txt              0
# region_txt               0
# provstate              421
# city                   434
# latitude              4556
# longitude             4557
# summary              66129
# success                  0
# attacktype1_txt          0
# targtype1_txt            0
# targsubtype1_txt     10373
# corp1                42550
# target1                636
# gname                    0
# motive              131130
# individual               0
# claimmode_txt       162608
# weaptype1_txt            0
# weapsubtype1_txt     20768
# weapdetail           67670
# nkill                10313
# nkillus              64446
# nkillter             66958
# nwound               16311
# nwoundus             64702
# nwoundte             69143
# property                 0
# propextent          117626
# propextent_txt      117626
# propvalue           142702
# ...

# %%
col=['propvalue','propcomment']
df=df.drop(columns=col,axis=1)

# %%
col=['scite1','scite2','scite3','propextent','propextent_txt','addnotes','claimmode_txt']
df=df.drop(columns=col,axis=1)

# %%
df.isnull().sum()
# Out:
# eventid                  0
# iyear                    0
# imonth                   0
# iday                     0
# country_txt              0
# region_txt               0
# provstate              421
# city                   434
# latitude              4556
# longitude             4557
# summary              66129
# success                  0
# attacktype1_txt          0
# targtype1_txt            0
# targsubtype1_txt     10373
# corp1                42550
# target1                636
# gname                    0
# motive              131130
# individual               0
# weaptype1_txt            0
# weapsubtype1_txt     20768
# weapdetail           67670
# nkill                10313
# nkillus              64446
# nkillter             66958
# nwound               16311
# nwoundus             64702
# nwoundte             69143
# property                 0
# dbsource                 0
# dtype: int64

# %%
print("total number of null values = ",df.isnull().sum().sum())
# Out:
# total number of null values =  641097

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 31 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   eventid           181691 non-null  object
#  1   iyear             181691 non-null  object
#  2   imonth            181691 non-null  object
#  3   iday              181691 non-null  object
#  4   country_txt       181691 non-null  object
#  5   region_txt        181691 non-null  object
#  6   provstate         181270 non-null  object
#  7   city              181257 non-null  object
#  8   latitude          177135 non-null  object
#  9   longitude         177134 non-null  object
#  10  summary           115562 non-null  object
#  11  success           181691 non-null  object
#  12  attacktype1_txt   181691 non-null  object
#  13  targtype1_txt     181691 non-null  object
#  14  targsubtype1_txt  171318 non-null  object
#  15  corp1             139141 non-null  object
# ...

# %%
df.describe()
# Out:
#             eventid   iyear  imonth    iday country_txt  \
# count        181691  181691  181691  181691      181691
# unique          576      47      13      32         205
# top     2.01407E+11    2014       5      15        Iraq
# freq           1726   16903   16875    6500       24636
#
#                         region_txt provstate     city   latitude  longitude  \
# count                       181691    181270   181257     177135     177134
# unique                          12      2855    36674      48322      48039
# top     Middle East & North Africa   Baghdad  Unknown  33.303566  44.371773
# freq                         50474      7645     9775       7521       7521
#
#         ...        weapsubtype1_txt weapdetail   nkill nkillus nkillter  \
# count   ...                  160923     114021  171378  117245   114733
# unique  ...                      30      19148     205      31       96
# top     ...  Unknown Explosive Type  Explosive       0       0        0
# ...

# %%
df.shape
# Out:
# (181691, 31)

# %%
df.dtypes
# Out:
# eventid             object
# iyear               object
# imonth              object
# iday                object
# country_txt         object
# region_txt          object
# provstate           object
# city                object
# latitude            object
# longitude           object
# summary             object
# success             object
# attacktype1_txt     object
# targtype1_txt       object
# targsubtype1_txt    object
# corp1               object
# target1             object
# gname               object
# motive              object
# individual          object
# weaptype1_txt       object
# weapsubtype1_txt    object
# weapdetail          object
# nkill               object
# nkillus             object
# nkillter            object
# nwound              object
# nwoundus            object
# nwoundte            object
# property            object
# dbsource            object
# dtype: object

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'country_txt', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'summary', 'success',
#        'attacktype1_txt', 'targtype1_txt', 'targsubtype1_txt', 'corp1',
#        'target1', 'gname', 'motive', 'individual', 'weaptype1_txt',
#        'weapsubtype1_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'dbsource'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 9193

# %%
df.nunique()
# Out:
# eventid                576
# iyear                   47
# imonth                  13
# iday                    32
# country_txt            205
# region_txt              12
# provstate             2855
# city                 36674
# latitude             48322
# longitude            48039
# summary             112492
# success                  2
# attacktype1_txt          9
# targtype1_txt           22
# targsubtype1_txt       112
# corp1                33238
# target1              86006
# gname                 3537
# motive               14490
# individual               2
# weaptype1_txt           12
# weapsubtype1_txt        30
# weapdetail           19148
# nkill                  205
# nkillus                 31
# nkillter                96
# nwound                 238
# nwoundus                44
# nwoundte                44
# property                 3
# dbsource                26
# dtype: int64

# %%
df.head(9)
# Out:
#        eventid iyear imonth iday         country_txt  \
# 0     1.97E+11  1970      7    2  Dominican Republic
# 1     1.97E+11  1970      0    0              Mexico
# 2  1.97001E+11  1970      1    0         Philippines
# 3  1.97001E+11  1970      1    0              Greece
# 4  1.97001E+11  1970      1    0               Japan
# 5  1.97001E+11  1970      1    1       United States
# 6  1.97001E+11  1970      1    2             Uruguay
# 7  1.97001E+11  1970      1    2       United States
# 8  1.97001E+11  1970      1    2       United States
#
#                     region_txt   provstate           city    latitude  \
# 0  Central America & Caribbean         NaN  Santo Domingo   18.456792
# 1                North America     Federal    Mexico city   19.371887
# 2               Southeast Asia      Tarlac        Unknown   15.478598
# 3               Western Europe      Attica         Athens    37.99749
# 4                    East Asia     Fukouka        Fukouka   33.580412
# ...

# %%
df=df.replace(np.nan, 0)

# %%
df.head(9)
# Out:
#        eventid iyear imonth iday         country_txt  \
# 0     1.97E+11  1970      7    2  Dominican Republic
# 1     1.97E+11  1970      0    0              Mexico
# 2  1.97001E+11  1970      1    0         Philippines
# 3  1.97001E+11  1970      1    0              Greece
# 4  1.97001E+11  1970      1    0               Japan
# 5  1.97001E+11  1970      1    1       United States
# 6  1.97001E+11  1970      1    2             Uruguay
# 7  1.97001E+11  1970      1    2       United States
# 8  1.97001E+11  1970      1    2       United States
#
#                     region_txt   provstate           city    latitude  \
# 0  Central America & Caribbean           0  Santo Domingo   18.456792
# 1                North America     Federal    Mexico city   19.371887
# 2               Southeast Asia      Tarlac        Unknown   15.478598
# 3               Western Europe      Attica         Athens    37.99749
# 4                    East Asia     Fukouka        Fukouka   33.580412
# ...

# %%
df.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.isnull().sum()
# Out:
# eventid             0
# iyear               0
# imonth              0
# iday                0
# country_txt         0
# region_txt          0
# provstate           0
# city                0
# latitude            0
# longitude           0
# summary             0
# success             0
# attacktype1_txt     0
# targtype1_txt       0
# targsubtype1_txt    0
# corp1               0
# target1             0
# gname               0
# motive              0
# individual          0
# weaptype1_txt       0
# weapsubtype1_txt    0
# weapdetail          0
# nkill               0
# nkillus             0
# nkillter            0
# nwound              0
# nwoundus            0
# nwoundte            0
# property            0
# dbsource            0
# dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.countplot(x=df['iyear'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(35,18))
sns.countplot(x=df['country_txt'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x=df['weaptype1_txt'])
plt.xticks(rotation=90)
plt.show()

# %%
grouped=pd.DataFrame(df.groupby(['country_txt','region_txt','provstate','city','weaptype1_txt','attacktype1_txt','gname','motive','iyear'])['eventid','imonth','iday','latitude','longitude','summary','success','targtype1_txt','targsubtype1_txt','corp1','target1','individual','weapsubtype1_txt','weapdetail','nkill','nkillus','nkillter','nwound','nwoundus','nwoundte','property',
'dbsource'].sum().reset_index())
# Out:
# <ipython-input-29-bff354f5409e>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped=pd.DataFrame(df.groupby(['country_txt','region_txt','provstate','city','weaptype1_txt','attacktype1_txt','gname','motive','iyear'])['eventid','imonth','iday','latitude','longitude','summary','success','targtype1_txt','targsubtype1_txt','corp1','target1','individual','weapsubtype1_txt','weapdetail','nkill','nkillus','nkillter','nwound','nwoundus','nwoundte','property',

# %%
grouped
# Out:
#         country_txt          region_txt   provstate                   city  \
# 0       Afghanistan          South Asia  Badakhshan                      0
# 1       Afghanistan          South Asia  Badakhshan                      0
# 2       Afghanistan          South Asia  Badakhshan  Arghanj Khaw district
# 3       Afghanistan          South Asia  Badakhshan  Arghanj Khaw district
# 4       Afghanistan          South Asia  Badakhshan       Baharak district
# ...             ...                 ...         ...                    ...
# 113457     Zimbabwe  Sub-Saharan Africa   Salisbury              Salisbury
# 113458     Zimbabwe  Sub-Saharan Africa     Unknown               Joromani
# 113459     Zimbabwe  Sub-Saharan Africa     Unknown                Unknown
# 113460     Zimbabwe  Sub-Saharan Africa     Unknown                Unknown
# 113461     Zimbabwe  Sub-Saharan Africa     Unknown                Unknown
#
#        weaptype1_txt              attacktype1_txt  \
# ...

# %%
plt.figure(figsize=(15,8))
sns.countplot(x=df1['region_txt'])
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-9c9f60b9b0cc> in <module>
#       1 plt.figure(figsize=(15,8))
# ----> 2 sns.countplot(x=df1['region_txt'])
#       3 plt.xticks(rotation=90)
#       4 plt.show()
#
# NameError: name 'df1' is not defined

# %%
plt.figure(figsize=(15,8))
sns.countplot(x=df1['attacktype1_txt'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Sample Geopandas plotting of Subset of data

# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
import numpy as np # linear algebra
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import dask.dataframe as dd

# %%
nf = pd.read_csv(r"C:\Users\dhole\Downloads\stunt1.csv",encoding='latin1',low_memory=False)

# %%
nf1=nf.replace(np.nan, 0)

# %%
gdf = geopandas.GeoDataFrame(nf1, geometry=geopandas.points_from_xy(nf1.longitude, nf1.latitude))

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

# We restrict to South America.
ax = world.plot(
    color='white', edgecolor='black')

# We can now plot our GeoDataFrame.
gdf.plot(ax=ax, color='red')

plt.show()
